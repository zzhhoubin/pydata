# %%
import pandas as pd
import quandl

# %%
# quandl.ApiConfig.api_key = 'KuCdQGSsXyQkgVrdtJjE'
sunspots = quandl.get('SIDC/SUNSPOTS_A')

# %%
sunspots.head(6)  #前n条记录
# Out:
#             Yearly Mean Total Sunspot Number  Yearly Mean Standard Deviation  \
# Date
# 1700-12-31                               8.3                             NaN
# 1701-12-31                              18.3                             NaN
# 1702-12-31                              26.7                             NaN
# 1703-12-31                              38.3                             NaN
# 1704-12-31                              60.0                             NaN
# 1705-12-31                              96.7                             NaN
#
#             Number of Observations  Definitive/Provisional Indicator
# Date
# 1700-12-31                     NaN                               1.0
# 1701-12-31                     NaN                               1.0
# 1702-12-31                     NaN                               1.0
# 1703-12-31                     NaN                               1.0
# 1704-12-31                     NaN                               1.0
# ...

# %%
sunspots.tail(6)  #后n条记录
# Out:
#             Yearly Mean Total Sunspot Number  Yearly Mean Standard Deviation  \
# Date
# 2012-12-31                              84.5                             6.7
# 2013-12-31                              94.0                             6.9
# 2014-12-31                             113.3                             8.0
# 2015-12-31                              69.8                             6.4
# 2016-12-31                              39.8                             3.9
# 2017-12-31                              21.8                             2.6
#
#             Number of Observations  Definitive/Provisional Indicator
# Date
# 2012-12-31                  5753.0                               1.0
# 2013-12-31                  5347.0                               1.0
# 2014-12-31                  5273.0                               1.0
# 2015-12-31                  8903.0                               1.0
# 2016-12-31                  9940.0                               1.0
# ...

# %%
last_date = sunspots.index[-1]  #取最新一年的索引

# %%
sunspots.loc[last_date]  #取最新一年的数据
# Out:
# Yearly Mean Total Sunspot Number       21.8
# Yearly Mean Standard Deviation          2.6
# Number of Observations              10734.0
# Definitive/Provisional Indicator        0.0
# Name: 2017-12-31 00:00:00, dtype: float64

# %%
sunspots["20070101":"20171231"]  #通过YYYYMMDD格式的日期字符串来查询日期
# Out:
#             Yearly Mean Total Sunspot Number  Yearly Mean Standard Deviation  \
# Date
# 2007-12-31                              12.6                             2.7
# 2008-12-31                               4.2                             2.5
# 2009-12-31                               4.8                             2.5
# 2010-12-31                              24.9                             3.4
# 2011-12-31                              80.8                             6.7
# 2012-12-31                              84.5                             6.7
# 2013-12-31                              94.0                             6.9
# 2014-12-31                             113.3                             8.0
# 2015-12-31                              69.8                             6.4
# 2016-12-31                              39.8                             3.9
# 2017-12-31                              21.8                             2.6
#
# ...

# %%
sunspots.iloc[[2,4,-2,-4]]  #索引列表也可以用于查询第2，4，-2，-4的值，sunspots.iloc[2]
# Out:
#             Yearly Mean Total Sunspot Number  Yearly Mean Standard Deviation  \
# Date
# 1702-12-31                              26.7                             NaN
# 1704-12-31                              60.0                             NaN
# 2016-12-31                              39.8                             3.9
# 2014-12-31                             113.3                             8.0
#
#             Number of Observations  Definitive/Provisional Indicator
# Date
# 1702-12-31                     NaN                               1.0
# 1704-12-31                     NaN                               1.0
# 2016-12-31                  9940.0                               1.0
# 2014-12-31                  5273.0                               1.0

# %%
sunspots.iloc[0,0]  #通过索引查询标量值,第一个表示行,第二个表示列
# Out:
# 8.3000000000000007

# %%
sunspots.iat[-1,0]  #通过索引查询标量值,第一个表示行,第二个表示列,速度更快
# Out:
# 21.800000000000001

# %%
sunspots[sunspots>sunspots.mean]  #查询布尔型变量的方法，查询所有数据行，与条件不符的行赋予Nan值
# Out:
#             Yearly Mean Total Sunspot Number  Yearly Mean Standard Deviation  \
# Date
# 1700-12-31                               8.3                             NaN
# 1701-12-31                              18.3                             NaN
# 1702-12-31                              26.7                             NaN
# 1703-12-31                              38.3                             NaN
# 1704-12-31                              60.0                             NaN
# 1705-12-31                              96.7                             NaN
# 1706-12-31                              48.3                             NaN
# 1707-12-31                              33.3                             NaN
# 1708-12-31                              16.7                             NaN
# 1709-12-31                              13.3                             NaN
# 1710-12-31                               5.0                             NaN
# ...

# %%
sunspots.describe()  #返回描述性统计信息，例如每行的非Nan数据项数量，mean值，std值，min值，max值，各种位数
# Out:
#        Yearly Mean Total Sunspot Number  Yearly Mean Standard Deviation  \
# count                        318.000000                      200.000000
# mean                          79.197170                        7.982500
# std                           61.985246                        3.818567
# min                            0.000000                        1.700000
# 25%                           24.950000                        4.700000
# 50%                           66.250000                        7.650000
# 75%                          116.025000                       10.425000
# max                          269.300000                       19.100000
#
#        Number of Observations  Definitive/Provisional Indicator
# count              200.000000                        318.000000
# mean              1514.010000                          0.996855
# std               2543.569835                          0.056077
# ...

# %%
sunspots.count()  #返回每行非Nan的数据的数量
# Out:
# Yearly Mean Total Sunspot Number    318
# Yearly Mean Standard Deviation      200
# Number of Observations              200
# Definitive/Provisional Indicator    318
# dtype: int64

# %%
sunspots.mad()  #每行平均绝对误差,类似于标准差的一个有力的统计工具
# Out:
# Yearly Mean Total Sunspot Number      50.921900
# Yearly Mean Standard Deviation         3.138625
# Number of Observations              1904.956300
# Definitive/Provisional Indicator       0.006270
# dtype: float64

# %%
sunspots.median()  #每行的中位数
# Out:
# Yearly Mean Total Sunspot Number     66.25
# Yearly Mean Standard Deviation        7.65
# Number of Observations              365.00
# Definitive/Provisional Indicator      1.00
# dtype: float64

# %%
sunspots.min()  #最小值
# Out:
# Yearly Mean Total Sunspot Number      0.0
# Yearly Mean Standard Deviation        1.7
# Number of Observations              150.0
# Definitive/Provisional Indicator      0.0
# dtype: float64

# %%
sunspots.max()  #最大值
# Out:
# Yearly Mean Total Sunspot Number      269.3
# Yearly Mean Standard Deviation         19.1
# Number of Observations              10734.0
# Definitive/Provisional Indicator        1.0
# dtype: float64

# %%
sunspots.mode()  #返回一个众数，即出现次数最多的数
# Out:
#    Yearly Mean Total Sunspot Number  Yearly Mean Standard Deviation  \
# 0                              18.3                             9.2
#
#    Number of Observations  Definitive/Provisional Indicator
# 0                   365.0                               1.0

# %%
sunspots.std()  #标准差，方差的平方根
# Out:
# Yearly Mean Total Sunspot Number      61.985246
# Yearly Mean Standard Deviation         3.818567
# Number of Observations              2543.569835
# Definitive/Provisional Indicator       0.056077
# dtype: float64

# %%
sunspots.var()  #返回方差
# Out:
# Yearly Mean Total Sunspot Number    3.842171e+03
# Yearly Mean Standard Deviation      1.458145e+01
# Number of Observations              6.469748e+06
# Definitive/Provisional Indicator    3.144654e-03
# dtype: float64

# %%
sunspots.skew()  #偏态系数，即数据分布的对称程度
# Out:
# Yearly Mean Total Sunspot Number     0.808667
# Yearly Mean Standard Deviation       0.561499
# Number of Observations               1.883133
# Definitive/Provisional Indicator   -17.832555
# dtype: float64

# %%
sunspots.kurt()  #返回数据分布曲线顶端尖峭或扁平程度
# Out:
# Yearly Mean Total Sunspot Number     -0.129786
# Yearly Mean Standard Deviation       -0.249446
# Number of Observations                2.013276
# Definitive/Provisional Indicator    318.000000
# dtype: float64
